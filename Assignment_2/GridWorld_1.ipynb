# %%
# The following code was adapted from a demo given by Andreas Krause in the course Probabilistic AI at ETH in 2021.

import numpy as np

import torch
from torch.distributions import Categorical
import matplotlib.pyplot as plt
import copy 

from rllib.environment.mdps import EasyGridWorld
from rllib.value_function import TabularValueFunction
from rllib.policy import TabularPolicy

environment = EasyGridWorld()
gamma = 0.9

# Plotters
def policy2str(policy):
    left = u'\u2190'
    right = u'\u2192'
    up = u'\u2191'
    down = u'\u2193'
    policy_str = ""
    if 0 == policy:
        policy_str += down 
    if 1 == policy:
        policy_str += up 
    if 2 == policy:
        policy_str += right
    if 3 == policy:
        policy_str += left
    return policy_str

def plot_value_function(value_function, ax):
    ax.imshow(value_function, vmin=-1, vmax=30)
    rows, cols = value_function.shape
    for row in range(rows):
        for col in range(cols):
            ax.text(row, col, f"{value_function[col, row]:.1f}", ha="center", va="center", color="w", fontsize=24)

def plot_policy(policy, ax):
    rows, cols = policy.shape
    ax.imshow(np.zeros((rows, cols)))
    for row in range(environment.height):
        for col in range(environment.width):
            ax.text(col, row, policy2str(policy[row, col]), ha="center", va="center", color="r", fontsize=24)

def plot_value_and_policy(value_function, policy):
    fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(20, 8))

    plot_value_function(value_function, axes[0])
    plot_policy(policy, axes[1])

# %% [markdown]
# ## Task 1 - Policy Evaluation

# %%
def init_policy_and_value_function(environment):
    ### ---Task 1.1--- ###
    ### YOUR CODE HERE ###
    # initalize the policy with the number of states and actions given by the environment
    policy = TabularPolicy(environment.num_states, environment.num_actions)

    # initalize the value_function with the number of states given by the environment
    value_function = TabularValueFunction(num_states =environment.num_states)
    
    ### YOUR CODE END  ###
    
    return policy, value_function

def linear_system_policy_evaluation(environment, policy, gamma, value_function):

    P, r = build_mrp_matrices(environment=environment, policy=policy)

    ### ---Task 1.2--- ###
    ### YOUR CODE HERE ###
    # calculate the values for each state according to the mrp_matrix
    vals = torch.inverse(torch.eye(environment.num_states) - gamma * P) @ r # @ is matrix multiplication
    
    ### YOUR CODE END  ###    
    
    for state in range(environment.num_states):
        value_function.set_value(state, vals[state].item())

    return value_function

def build_mrp_matrices(environment, policy):
    mrp_kernel = np.zeros((environment.num_states, environment.num_states))
    mrp_reward = np.zeros((environment.num_states))

    for state in range(environment.num_states):
        state = torch.tensor(state).long()
        policy_ = Categorical(logits=policy(state))

        for a, p_action in enumerate(policy_.probs):
            for transition in environment.transitions[(state.item(), a)]:
                with torch.no_grad():
                    p_ns = transition["probability"]
                    mrp_reward[state] += p_action * p_ns * transition["reward"]
                    mrp_kernel[state, transition["next_state"]
                               ] += p_action * p_ns

    return mrp_kernel, mrp_reward

### ---Task 1.3--- ###
policy, value_function = init_policy_and_value_function(environment)
value_function = linear_system_policy_evaluation(environment, policy, gamma, value_function)

plot_value_and_policy(value_function.table.reshape(5, 5).detach().numpy(),
                      policy.table.argmax(0).reshape(5, 5).detach().numpy())

# %% [markdown]
# ## Task 2 - Policy Iteration

# %%
# Policy Iteration
def policy_iteration(environment, gamma):
    """Implement Policy Iteration algorithm.

    Parameters
    ----------
    gamma: float.
        discount factor.

    References
    ----------
    Sutton, R. S., & Barto, A. G. (2018). Reinforcement learning: An introduction.
    MIT press.
    Chapter 4.3

    """
    
    policy, value_function = init_policy_and_value_function(environment)
    
    i = 0
    while True:
        i += 1
        print(f"Policy Iteration {i}")
        # Evaluate the policy.
        value_function = linear_system_policy_evaluation(environment, policy, gamma, value_function) # start from linear policy evaluation

        policy_stable = True
        # iterate through all states
        for state in range(environment.num_states):
            # initialize values
            value_ = torch.zeros(environment.num_actions)
            
            # iterate through possible actions
            for action in range(environment.num_actions):
                value_estimate = 0
                
                # iterate through transitions
                for transition in environment.transitions[(state, action)]:
                    next_state = torch.tensor(transition["next_state"]).long()
                    reward = torch.tensor(transition["reward"]).double()
                    transition_probability = transition["probability"]

                    ### ---Task 2.1--- ###
                    ### YOUR CODE HERE ###
                    value_estimate += transition_probability * (reward + gamma * value_function(next_state)) # calculate value estimate
                    
                    ### YOUR CODE END

                value_[action] = value_estimate

            state = torch.tensor(state).long()
            old_policy = policy(state)
            old_action = torch.argmax(old_policy)

            action = torch.argmax(value_)
            policy.set_value(state, action)
            
            ### ---Task 2.2--- ###
            ### YOUR CODE HERE ###
            if old_action != action:
                policy_stable = False # if policy is not stable, we need to iterate again
            
            ### YOUR CODE END  ###

        if policy_stable:
            break

    return value_function, policy

### ---Task 2.3--- ###
value_function, policy = policy_iteration(environment, gamma)
plot_value_and_policy(value_function.table.reshape(5, 5).detach().numpy(),
                      policy.table.argmax(0).reshape(5, 5).detach().numpy())
# Out:
# Policy Iteration 1
# Policy Iteration 2
# Policy Iteration 3
# Policy Iteration 4
# Policy Iteration 5

# %% [markdown]
# ## Task 3 - Value Iteration

# %%
def value_iteration(environment, gamma, eps=1e-6, max_iter=1000):
    """Implement of Value Iteration algorithm.

    Parameters
    ----------
    gamma: float
        discount factor.
    eps: float 
        desired precision.
    max_iter: int 
        Max number of iterations. 
    value_function: TabularValueFunction, optional. 
        Initial value function. 
        
    Returns
    -------
    value_function: TabularValueFunction
        Optimal value function.
    policy: Tabular Policy 
        Optimal policy. 
    num_iter: int
        Number of iterations to reach `eps' accuracy. 

    References
    ----------
    Sutton, R. S., & Barto, A. G. (2018). Reinforcement learning: An introduction.
    MIT press.
    Chapter 4.4

    """
    policy, value_function = init_policy_and_value_function(environment)
    
    for num_iter in range(max_iter):
        print("Iteration:", num_iter)
        
        error = 0

        old_value_function = copy.deepcopy(value_function)
        for state in range(environment.num_states):
            ### ---TASK 3.1--- ###
            ### YOUR CODE HERE ###
            value_ = torch.zeros(environment.num_actions) # initialize action values for each state
            ### YOUR CODE END ###
            
            for action in range(environment.num_actions):
                value_estimate = 0

                # In practice, we do not have access to environment.transitions, but only to samples of it!.
                for transition in environment.transitions[(state, action)]:  
                    next_state = torch.tensor(transition["next_state"]).long()
                    reward = torch.tensor(transition["reward"]).double()
                    transition_probability = transition["probability"]
                    
                    ### ---TASK 3.2--- ###
                    ### YOUR CODE HERE ###
                    value_estimate += transition_probability * (reward + gamma * old_value_function(next_state))
                value_[action] = value_estimate
            action = torch.argmax(value_) # select best action   
            state = torch.tensor(state).long()
            # update value function with the current best action value, here is the main difference between policy iteration and value iteration!
            value_function.set_value(state, value_[action]) 
            ### YOUR CODE END ###
            
            ### ---TASK 3.3--- ###
            ### YOUR CODE HERE ###
            error = max(error, abs(value_[action] - old_value_function(state))) # compute error, record max error
            ### YOUR CODE END ### 
            
            policy.set_value(state, action)

        print("Error:", error)
        if error < eps:
            break

    return value_function, policy, num_iter 

### ---Task 3.4--- ###
value_function, policy, num_iter = value_iteration(environment, gamma, eps=1e-6, max_iter=1000)
plot_value_and_policy(value_function.table.reshape(5, 5).detach().numpy(),
                      policy.table.argmax(0).reshape(5, 5).detach().numpy())
print(f"Iterations until convergence: {num_iter}")
# Out:
# Iteration: 0
# Error: tensor([10.], grad_fn=<AbsBackward0>)
# Iteration: 1
# Error: tensor([9.], grad_fn=<AbsBackward0>)
# Iteration: 2
# Error: tensor([8.1000], grad_fn=<AbsBackward0>)
# Iteration: 3
# Error: tensor([7.2900], grad_fn=<AbsBackward0>)
# Iteration: 4
# Error: tensor([6.5610], grad_fn=<AbsBackward0>)
# Iteration: 5
# Error: tensor([5.9049], grad_fn=<AbsBackward0>)
# Iteration: 6
# Error: tensor([5.3144], grad_fn=<AbsBackward0>)
# Iteration: 7
# Error: tensor([4.7830], grad_fn=<AbsBackward0>)
# Iteration: 8
# Error: tensor([4.3047], grad_fn=<AbsBackward0>)
# Iteration: 9
# Error: tensor([3.8742], grad_fn=<AbsBackward0>)
# Iteration: 10
# Error: tensor([3.4868], grad_fn=<AbsBackward0>)
# Iteration: 11
# Error: tensor([3.1381], grad_fn=<AbsBackward0>)
# Iteration: 12
# Error: tensor([2.8243], grad_fn=<AbsBackward0>)
# Iteration: 13
# Error: tensor([2.5419], grad_fn=<AbsBackward0>)
# Iteration: 14
# Error: tensor([2.2877], grad_fn=<AbsBackward0>)
# Iteration: 15
# Error: tensor([2.0589], grad_fn=<AbsBackward0>)
# Iteration: 16
# Error: tensor([1.8530], grad_fn=<AbsBackward0>)
# Iteration: 17
# Error: tensor([1.6677], grad_fn=<AbsBackward0>)
# Iteration: 18
# Error: tensor([1.5009], grad_fn=<AbsBackward0>)
# Iteration: 19
# Error: tensor([1.3509], grad_fn=<AbsBackward0>)
# Iteration: 20
# Error: tensor([1.2158], grad_fn=<AbsBackward0>)
# Iteration: 21
# Error: tensor([1.0942], grad_fn=<AbsBackward0>)
# Iteration: 22
# Error: tensor([0.9848], grad_fn=<AbsBackward0>)
# Iteration: 23
# Error: tensor([0.8863], grad_fn=<AbsBackward0>)
# Iteration: 24
# Error: tensor([0.7977], grad_fn=<AbsBackward0>)
# Iteration: 25
# Error: tensor([0.7179], grad_fn=<AbsBackward0>)
# Iteration: 26
# Error: tensor([0.6461], grad_fn=<AbsBackward0>)
# Iteration: 27
# Error: tensor([0.5815], grad_fn=<AbsBackward0>)
# Iteration: 28
# Error: tensor([0.5233], grad_fn=<AbsBackward0>)
# Iteration: 29
# Error: tensor([0.4710], grad_fn=<AbsBackward0>)
# Iteration: 30
# Error: tensor([0.4239], grad_fn=<AbsBackward0>)
# Iteration: 31
# Error: tensor([0.3815], grad_fn=<AbsBackward0>)
# Iteration: 32
# Error: tensor([0.3434], grad_fn=<AbsBackward0>)
# Iteration: 33
# Error: tensor([0.3090], grad_fn=<AbsBackward0>)
# Iteration: 34
# Error: tensor([0.2781], grad_fn=<AbsBackward0>)
# Iteration: 35
# Error: tensor([0.2503], grad_fn=<AbsBackward0>)
# Iteration: 36
# Error: tensor([0.2253], grad_fn=<AbsBackward0>)
# Iteration: 37
# Error: tensor([0.2028], grad_fn=<AbsBackward0>)
# Iteration: 38
# Error: tensor([0.1825], grad_fn=<AbsBackward0>)
# Iteration: 39
# Error: tensor([0.1642], grad_fn=<AbsBackward0>)
# Iteration: 40
# Error: tensor([0.1478], grad_fn=<AbsBackward0>)
# Iteration: 41
# Error: tensor([0.1330], grad_fn=<AbsBackward0>)
# Iteration: 42
# Error: tensor([0.1197], grad_fn=<AbsBackward0>)
# Iteration: 43
# Error: tensor([0.1078], grad_fn=<AbsBackward0>)
# Iteration: 44
# Error: tensor([0.0970], grad_fn=<AbsBackward0>)
# Iteration: 45
# Error: tensor([0.0873], grad_fn=<AbsBackward0>)
# Iteration: 46
# Error: tensor([0.0786], grad_fn=<AbsBackward0>)
# Iteration: 47
# Error: tensor([0.0707], grad_fn=<AbsBackward0>)
# Iteration: 48
# Error: tensor([0.0636], grad_fn=<AbsBackward0>)
# Iteration: 49
# Error: tensor([0.0573], grad_fn=<AbsBackward0>)
# Iteration: 50
# Error: tensor([0.0515], grad_fn=<AbsBackward0>)
# Iteration: 51
# Error: tensor([0.0464], grad_fn=<AbsBackward0>)
# Iteration: 52
# Error: tensor([0.0417], grad_fn=<AbsBackward0>)
# Iteration: 53
# Error: tensor([0.0376], grad_fn=<AbsBackward0>)
# Iteration: 54
# Error: tensor([0.0338], grad_fn=<AbsBackward0>)
# Iteration: 55
# Error: tensor([0.0304], grad_fn=<AbsBackward0>)
# Iteration: 56
# Error: tensor([0.0274], grad_fn=<AbsBackward0>)
# Iteration: 57
# Error: tensor([0.0247], grad_fn=<AbsBackward0>)
# Iteration: 58
# Error: tensor([0.0222], grad_fn=<AbsBackward0>)
# Iteration: 59
# Error: tensor([0.0200], grad_fn=<AbsBackward0>)
# Iteration: 60
# Error: tensor([0.0180], grad_fn=<AbsBackward0>)
# Iteration: 61
# Error: tensor([0.0162], grad_fn=<AbsBackward0>)
# Iteration: 62
# Error: tensor([0.0146], grad_fn=<AbsBackward0>)
# Iteration: 63
# Error: tensor([0.0131], grad_fn=<AbsBackward0>)
# Iteration: 64
# Error: tensor([0.0118], grad_fn=<AbsBackward0>)
# Iteration: 65
# Error: tensor([0.0106], grad_fn=<AbsBackward0>)
# Iteration: 66
# Error: tensor([0.0096], grad_fn=<AbsBackward0>)
# Iteration: 67
# Error: tensor([0.0086], grad_fn=<AbsBackward0>)
# Iteration: 68
# Error: tensor([0.0077], grad_fn=<AbsBackward0>)
# Iteration: 69
# Error: tensor([0.0070], grad_fn=<AbsBackward0>)
# Iteration: 70
# Error: tensor([0.0063], grad_fn=<AbsBackward0>)
# Iteration: 71
# Error: tensor([0.0056], grad_fn=<AbsBackward0>)
# Iteration: 72
# Error: tensor([0.0051], grad_fn=<AbsBackward0>)
# Iteration: 73
# Error: tensor([0.0046], grad_fn=<AbsBackward0>)
# Iteration: 74
# Error: tensor([0.0041], grad_fn=<AbsBackward0>)
# Iteration: 75
# Error: tensor([0.0037], grad_fn=<AbsBackward0>)
# Iteration: 76
# Error: tensor([0.0033], grad_fn=<AbsBackward0>)
# Iteration: 77
# Error: tensor([0.0030], grad_fn=<AbsBackward0>)
# Iteration: 78
# Error: tensor([0.0027], grad_fn=<AbsBackward0>)
# Iteration: 79
# Error: tensor([0.0024], grad_fn=<AbsBackward0>)
# Iteration: 80
# Error: tensor([0.0022], grad_fn=<AbsBackward0>)
# Iteration: 81
# Error: tensor([0.0020], grad_fn=<AbsBackward0>)
# Iteration: 82
# Error: tensor([0.0018], grad_fn=<AbsBackward0>)
# Iteration: 83
# Error: tensor([0.0016], grad_fn=<AbsBackward0>)
# Iteration: 84
# Error: tensor([0.0014], grad_fn=<AbsBackward0>)
# Iteration: 85
# Error: tensor([0.0013], grad_fn=<AbsBackward0>)
# Iteration: 86
# Error: tensor([0.0012], grad_fn=<AbsBackward0>)
# Iteration: 87
# Error: tensor([0.0010], grad_fn=<AbsBackward0>)
# Iteration: 88
# Error: tensor([0.0009], grad_fn=<AbsBackward0>)
# Iteration: 89
# Error: tensor([0.0008], grad_fn=<AbsBackward0>)
# Iteration: 90
# Error: tensor([0.0008], grad_fn=<AbsBackward0>)
# Iteration: 91
# Error: tensor([0.0007], grad_fn=<AbsBackward0>)
# Iteration: 92
# Error: tensor([0.0006], grad_fn=<AbsBackward0>)
# Iteration: 93
# Error: tensor([0.0006], grad_fn=<AbsBackward0>)
# Iteration: 94
# Error: tensor([0.0005], grad_fn=<AbsBackward0>)
# Iteration: 95
# Error: tensor([0.0005], grad_fn=<AbsBackward0>)
# Iteration: 96
# Error: tensor([0.0004], grad_fn=<AbsBackward0>)
# Iteration: 97
# Error: tensor([0.0004], grad_fn=<AbsBackward0>)
# Iteration: 98
# Error: tensor([0.0003], grad_fn=<AbsBackward0>)
# Iteration: 99
# Error: tensor([0.0003], grad_fn=<AbsBackward0>)
# Iteration: 100
# Error: tensor([0.0003], grad_fn=<AbsBackward0>)
# Iteration: 101
# Error: tensor([0.0002], grad_fn=<AbsBackward0>)
# Iteration: 102
# Error: tensor([0.0002], grad_fn=<AbsBackward0>)
# Iteration: 103
# Error: tensor([0.0002], grad_fn=<AbsBackward0>)
# Iteration: 104
# Error: tensor([0.0002], grad_fn=<AbsBackward0>)
# Iteration: 105
# Error: tensor([0.0002], grad_fn=<AbsBackward0>)
# Iteration: 106
# Error: tensor([0.0001], grad_fn=<AbsBackward0>)
# Iteration: 107
# Error: tensor([0.0001], grad_fn=<AbsBackward0>)
# Iteration: 108
# Error: tensor([0.0001], grad_fn=<AbsBackward0>)
# Iteration: 109
# Error: tensor([0.0001], grad_fn=<AbsBackward0>)
# Iteration: 110
# Error: tensor([9.3460e-05], grad_fn=<AbsBackward0>)
# Iteration: 111
# Error: tensor([8.5831e-05], grad_fn=<AbsBackward0>)
# Iteration: 112
# Error: tensor([7.6294e-05], grad_fn=<AbsBackward0>)
# Iteration: 113
# Error: tensor([6.8665e-05], grad_fn=<AbsBackward0>)
# Iteration: 114
# Error: tensor([6.1035e-05], grad_fn=<AbsBackward0>)
# Iteration: 115
# Error: tensor([5.5313e-05], grad_fn=<AbsBackward0>)
# Iteration: 116
# Error: tensor([5.0545e-05], grad_fn=<AbsBackward0>)
# Iteration: 117
# Error: tensor([4.4823e-05], grad_fn=<AbsBackward0>)
# Iteration: 118
# Error: tensor([3.8147e-05], grad_fn=<AbsBackward0>)
# Iteration: 119
# Error: tensor([3.4332e-05], grad_fn=<AbsBackward0>)
# Iteration: 120
# Error: tensor([3.0518e-05], grad_fn=<AbsBackward0>)
# Iteration: 121
# Error: tensor([2.6703e-05], grad_fn=<AbsBackward0>)
# Iteration: 122
# Error: tensor([2.4796e-05], grad_fn=<AbsBackward0>)
# Iteration: 123
# Error: tensor([2.2888e-05], grad_fn=<AbsBackward0>)
# Iteration: 124
# Error: tensor([2.0981e-05], grad_fn=<AbsBackward0>)
# Iteration: 125
# Error: tensor([1.9073e-05], grad_fn=<AbsBackward0>)
# Iteration: 126
# Error: tensor([1.7166e-05], grad_fn=<AbsBackward0>)
# Iteration: 127
# Error: tensor([1.5259e-05], grad_fn=<AbsBackward0>)
# Iteration: 128
# Error: tensor([1.3351e-05], grad_fn=<AbsBackward0>)
# Iteration: 129
# Error: tensor([1.1444e-05], grad_fn=<AbsBackward0>)
# Iteration: 130
# Error: tensor([1.1444e-05], grad_fn=<AbsBackward0>)
# Iteration: 131
# Error: tensor([1.1444e-05], grad_fn=<AbsBackward0>)
# Iteration: 132
# Error: tensor([9.5367e-06], grad_fn=<AbsBackward0>)
# Iteration: 133
# Error: tensor([9.5367e-06], grad_fn=<AbsBackward0>)
# Iteration: 134
# Error: tensor([9.5367e-06], grad_fn=<AbsBackward0>)
# Iteration: 135
# Error: tensor([8.5831e-06], grad_fn=<AbsBackward0>)
# Iteration: 136
# Error: tensor([7.6294e-06], grad_fn=<AbsBackward0>)
# Iteration: 137
# Error: tensor([6.6757e-06], grad_fn=<AbsBackward0>)
# Iteration: 138
# Error: tensor([5.7220e-06], grad_fn=<AbsBackward0>)
# Iteration: 139
# Error: tensor([3.8147e-06], grad_fn=<AbsBackward0>)
# Iteration: 140
# Error: tensor([3.8147e-06], grad_fn=<AbsBackward0>)
# Iteration: 141
# Error: tensor([3.8147e-06], grad_fn=<AbsBackward0>)
# Iteration: 142
# Error: tensor([3.8147e-06], grad_fn=<AbsBackward0>)
# Iteration: 143
# Error: tensor([1.9073e-06], grad_fn=<AbsBackward0>)
# Iteration: 144
# Error: tensor([1.9073e-06], grad_fn=<AbsBackward0>)
# Iteration: 145
# Error: tensor([9.5367e-07], grad_fn=<AbsBackward0>)
# Iterations until convergence: 145

# %% [markdown]
# ## Observation:
# Policy iteration and Value iteration achieve same results, while Policy iteration takes only 4 iterations and Value iteration takes 145 iterations.
